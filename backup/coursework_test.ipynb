# %% [markdown]
# # Importing Modules

# %%
import random
import pandas as pd
from operator import itemgetter

# %% [markdown]
# # Store information about teams and players.

# %%
Mumbai_India = ['Mumbai_India',r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Mumbai_India\\Mumbai_India.xlsx']
Chennai_SouthAfrica = ['Chennai_SouthAfrica',r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Chennai_SouthAfrica\\Chennai_SouthAfrica.xlsx']
Delhi_NewZealand = ['Delhi_NewZealand',r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Delhi_NewZealand\\Delhi_NewZealand.xlsx']
RoyalChallengers_Bangladesh = ['RoyalChallengers_Bangladesh',r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\RoyalChallengers_Bangladesh\\RoyalChallengers_Bangladesh.xlsx']
Rajastan_Australia =  ['Rajastan_Australia',r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Rajastan_Australia\\Rajastan_Australia.xlsx']
Kolkata_England = ['Kolkata_England',r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Kolkata_England\\Kolkata_England.xlsx']
Punjab_Pakistan = ['Punjab_Pakistan',r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Punjab_Pakistan\\Punjab_Pakistan.xlsx']
Sunrisers_SriLanka = ['Sunrisers_SriLanka',r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Sunrisers_SriLanka\\Sunrisers_SriLanka.xlsx']

# %%
#assinging teams to groups
Group_A = [Mumbai_India,Chennai_SouthAfrica,Delhi_NewZealand,RoyalChallengers_Bangladesh ]
Group_B = [Rajastan_Australia,Kolkata_England,Punjab_Pakistan,Sunrisers_SriLanka]

# %% [markdown]
# # the user can delete/edit player and team profiles and system needs to give separate options for each and every functionality

# %%
# sl = pd.read_excel(r'team data\groupA\sl.xlsx')
# england = pd.read_excel(r'team data\groupA\eng.xlsx')
# westIndies = pd.read_excel(r'team data\groupA\wi.xlsx')
# southAfrica = pd.read_excel(r'team data\groupA\sa.xlsx')
# india = pd.read_excel(r'team data\groupB\ind.xlsx')
# australia = pd.read_excel(r'team data\groupB\aus.xlsx')
# newZieland = pd.read_excel(r'team data\groupB\nz.xlsx')
# pakistan = pd.read_excel(r'team data\groupB\pak.xlsx')


# --------------------------------------------------------------------------India--------------------------------------------------------------------------------------
                        #   --------------------------------------To Do----------------------------------------------------
   
# def GetTeam(teamName):
#     print(GetTeam)
#     df = pd.read_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\'+teamName+'\\'+teamName+'.xlsx')
#     editable_options = df.iloc[:, :1]
#     print(editable_options)
    
# def EditTeam(teamName):
#     df = pd.read_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\'+teamName+'\\'+teamName+'.xlsx')
#     df.at[row, col] = val
#     print(df.iloc[:, 0])
#     df.to_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\'+teamName+'\\'+teamName+'.xlsx', index=False)
   
   
   
   
   
                        #   --------------------------------------To Do----------------------------------------------------
   
   
    
def India():
    df = pd.read_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Mumbai_India\\Mumbai_India.xlsx')
    editable_options = df.iloc[:, :1]
    print(editable_options)

def editInd():
    df = pd.read_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Mumbai_India\\Mumbai_India.xlsx')
    df.at[row, col] = val
    print(df.iloc[:, 0])
    df.to_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Mumbai_India\\Mumbai_India.xlsx', index=False)


# --------------------------------------------------------------------------SouthAfrica--------------------------------------------------------------------------------------

def SouthAfrica():
    df = pd.read_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Chennai_SouthAfrica\\Chennai_SouthAfrica.xlsx')
    editable_options = df.iloc[:, :1]
    print(editable_options)

def editSA():
    df = pd.read_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Chennai_SouthAfrica\\Chennai_SouthAfrica.xlsx')
    df.at[row, col] = val
    print(df.iloc[:, 0])
    df.to_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Chennai_SouthAfrica\\Chennai_SouthAfrica.xlsx', index=False)
    
    
# --------------------------------------------------------------------------NewZealand--------------------------------------------------------------------------------------

def NewZealand():
    df = pd.read_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Delhi_NewZealand\\Delhi_NewZealand.xlsx')
    editable_options = df.iloc[:, :1]
    print(editable_options)

def editNZ():
    df = pd.read_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Delhi_NewZealand\\Delhi_NewZealand.xlsx')
    df.at[row, col] = val
    print(df.iloc[:, 0])
    df.to_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Delhi_NewZealand\\Delhi_NewZealand.xlsx', index=False)


# --------------------------------------------------------------------------Bangladesh--------------------------------------------------------------------------------------

def Bangladesh():
    df = pd.read_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\RoyalChallengers_Bangladesh\\RoyalChallengers_Bangladesh.xlsx')
    editable_options = df.iloc[:, :1]
    print(editable_options)

def editBan():
    df = pd.read_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\RoyalChallengers_Bangladesh\\RoyalChallengers_Bangladesh.xlsx')
    df.at[row, col] = val
    print(df.iloc[:, 0])
    df.to_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\RoyalChallengers_Bangladesh\\RoyalChallengers_Bangladesh.xlsx', index=False)


# --------------------------------------------------------------------------Australia--------------------------------------------------------------------------------------

def Australia():
    df = pd.read_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Rajastan_Australia\\Rajastan_Australia.xlsx')
    editable_options = df.iloc[:, :1]
    print(editable_options)

def editAus():
    df = pd.read_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Rajastan_Australia\\Rajastan_Australia.xlsx')
    df.at[row, col] = val
    print(df.iloc[:, 0])
    df.to_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Rajastan_Australia\\Rajastan_Australia.xlsx', index=False)


# --------------------------------------------------------------------------England--------------------------------------------------------------------------------------

def England():
    df = pd.read_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Kolkata_England\\Kolkata_England.xlsx')
    editable_options = df.iloc[:, :1]
    print(editable_options)

def editEng():
    df = pd.read_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Kolkata_England\\Kolkata_England.xlsx')
    df.at[row, col] = val
    print(df.iloc[:, 0])
    df.to_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Kolkata_England\\Kolkata_England.xlsx', index=False)


# --------------------------------------------------------------------------Pakistan--------------------------------------------------------------------------------------

def Pakistan():
    df = pd.read_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Punjab_Pakistan\\Punjab_Pakistan.xlsx')
    editable_options = df.iloc[:, :1]
    print(editable_options)

def editPak():
    df = pd.read_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Punjab_Pakistan\\Punjab_Pakistan.xlsx')
    df.at[row, col] = val
    print(df.iloc[:, 0])
    df.to_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Punjab_Pakistan\\Punjab_Pakistan.xlsx', index=False)


# --------------------------------------------------------------------------SriLanka--------------------------------------------------------------------------------------

def SriLanka():
    df = pd.read_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Sunrisers_SriLanka\\Sunrisers_SriLanka.xlsx')
    editable_options = df.iloc[:, :1]
    print(editable_options)

def editSri():
    df = pd.read_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Sunrisers_SriLanka\\Sunrisers_SriLanka.xlsx')
    df.at[row, col] = val
    print(df.iloc[:, 0])
    df.to_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\Sunrisers_SriLanka\\Sunrisers_SriLanka.xlsx', index=False)

# %%
print("---------------IIT Cricket Premier League 2021---------------")
print()


getData = int(input("Do you want to see any team or player profiles?\n1 - yes \n0 - no \n Select 1 or 0 :  "))

while getData == 1:
    getGroup = int(input("Which group do you want to see? \n1 - group A \n2 - group B \n Select 1 or 2: "))
    if getGroup == 1:
        getTeam = int(input("Which team do you want to see? \n1 - Mumbai India \n2 - Chennai SouthAfrica \n3 - Delhi NewZealand \n4 - RoyalChallengers Bangladesh \n Select a number from 1 to 4 "))
        
        if getTeam == 1:
            # India()
            editTeam = int(input("Do you want to make any changes on team Mumbai India? \n1 - yes \n0 - no \n Select 1 or 0 :  "))
            while editTeam == 1:
                row = int(input("Which row do you want to edit? "))
                col = input("Column name you want to edit? ")
                val = input("What should be the change then? ")
                editInd()
                print("your changes have been saved successfully !!")
                editTeam = int(input("Do you want to make any changes on team Mumbai India again?\n1 - yes \n0 - no \n Select 1 or 0 :   "))
            else:
                getData = int(input("Do you want to see any other team or player profiles?\n1 - yes \n0 - no \n Select 1 or 0 :   "))
                        
        elif getTeam == 2:
            SouthAfrica()
            editTeam = int(input("Do you want to make any changes on team South Africa? \n1 - yes \n0 - no \n Select 1 or 0 :  "))
            while editTeam == 1:
                row = int(input("Which row do you want to edit? "))
                col = input("Column name you want to edit? ")
                val = input("What should be the change then? ")
                editSA()
                print("your changes have been saved successfully !!")
                editTeam = int(input("Do you want to make any changes on team South Africa again?\n1 - yes \n0 - no \n Select 1 or 0 :   "))
            else:
                getData = int(input("Do you want to see any other team or player profiles?\n1 - yes \n0 - no \n Select 1 or 0 :   "))
            
        elif getTeam == 3:
            NewZealand()
            editTeam = int(input("Do you want to make any changes on team New Zealand? \n1 - yes \n0 - no \n Select 1 or 0 :  "))
            while editTeam == 1:
                row = int(input("Which row do you want to edit? "))
                col = input("Column name you want to edit? ")
                val = input("What should be the change then? ")
                editNZ()
                print("your changes have been saved successfully !!")
                editTeam = int(input("Do you want to make any changes on team New Zealand again?\n1 - yes \n0 - no \n Select 1 or 0 :   "))
            else:
                getData = int(input("Do you want to see any other team or player profiles?\n1 - yes \n0 - no \n Select 1 or 0 :   "))            

        elif getTeam == 4:
            Bangladesh()
            editTeam = int(input("Do you want to make any changes on team Bangladesh? \n1 - yes \n0 - no \n Select 1 or 0 :  "))
            while editTeam == 1:
                row = int(input("Which row do you want to edit? "))
                col = input("Column name you want to edit? ")
                val = input("What should be the change then? ")
                editBan()
                print("your changes have been saved successfully !!")
                editTeam = int(input("Do you want to make any changes on team Bangladesh again?\n1 - yes \n0 - no \n Select 1 or 0 :   "))
            else:
                getData = int(input("Do you want to see any other team or player profiles?\n1 - yes \n0 - no \n Select 1 or 0 :   ")) 
            
            
    elif getGroup == 2:
        getTeam = int(input("Which team do you want to see? \n1 - Rajastan Australia \n2 - Kolkata England \n3 - Punjab Pakistan \n4 - Sunrisers SriLanka \n Select a number from 1 to 4"))
        if getTeam == 1:
            Australia()
            editTeam = int(input("Do you want to make any changes on team Rajastan Australia?\n1 - yes \n0 - no \n Select 1 or 0 :  "))
            while editTeam == 1:
                row = int(input("Which row do you want to edit? "))
                col = input("Column name you want to edit? ")
                val = input("What should be the change then? ")
                editAus()
                print("your changes have been saved successfully !!")
                editTeam = int(input("Do you want to make any changes on team Rajastan Australia again?\n1 - yes \n0 - no \n Select 1 or 0 :   "))
            else:
                getData = int(input("Do you want to see anyother team or player profiles?\n1 - yes \n0 - no \n Select 1 or 0 :   "))
                
        elif getTeam == 2:
            England()
            editTeam = int(input("Do you want to make any changes on team Kolkata England? \n1 - yes \n0 - no \n Select 1 or 0 :  "))
            while editTeam == 1:
                row = int(input("Which row do you want to edit? "))
                col = input("Column name you want to edit? ")
                val = input("What should be the change then? ")
                editEng()
                print("your changes have been saved successfully !!")
                editTeam = int(input("Do you want to make any changes on team Kolkata England again?\n1 - yes \n0 - no \n Select 1 or 0 :   "))
            else:
                getData = int(input("Do you want to see anyother team or player profiles?\n1 - yes \n0 - no \n Select 1 or 0 :   "))
                
        elif getTeam == 3:
            Pakistan()
            editTeam = int(input("Do you want to make any changes on team Punjab Pakistan? \n1 - yes \n0 - no \n Select 1 or 0 :  "))
            while editTeam == 1:
                row = int(input("Which row do you want to edit? "))
                col = input("Column name you want to edit? ")
                val = input("What should be the change then? ")
                editPak()
                print("your changes have been saved successfully !!")
                editTeam = int(input("Do you want to make any changes on team Punjab Pakistan again?\n1 - yes \n0 - no \n Select 1 or 0 :   "))
            else:
                getData = int(input("Do you want to see anyother team or player profiles?\n1 - yes \n0 - no \n Select 1 or 0 :   "))
                            
        elif getTeam == 4:
            SriLanka()
            editTeam = int(input("Do you want to make any changes on team Sunrisers SriLanka? \n1 - yes \n0 - no \n Select 1 or 0 :  "))
            while editTeam == 1:
                row = int(input("Which row do you want to edit? "))
                col = input("Column name you want to edit? ")
                val = input("What should be the change then? ")
                editSri()
                print("your changes have been saved successfully !!")
                editTeam = int(input("Do you want to make any changes on team Sunrisers SriLanka again?\n1 - yes \n0 - no \n Select 1 or 0 :   "))
            else:
                getData = int(input("Do you want to see anyother team or player profiles?\n1 - yes \n0 - no \n Select 1 or 0 :   "))             
            
            
            
            
            
            
            
            
            
            
            
            
            
            
            
            
            
# else:
#     checkSl = sl.isnull().values.any()
#     checkEng = england.isnull().sum().sum()
#     checkWi = westIndies.isnull().sum().sum()
#     checkSa = southAfrica.isnull().sum().sum()
#     chechInd = india.isnull().sum().sum()
#     checkAus = australia.isnull().sum().sum()
#     checkNz = newZieland.isnull().sum().sum()
#     checkPak = pakistan.isnull().sum().sum()

#     while checkSl != 0:
#         sriLanka()
#         raw = int(input("Which raw do you want to edit? "))
#         col = input("which column do you want to edit? ")
#         val = input("What should be the value then? ")
#         editSri()
#         sl = pd.read_excel(r'team data\groupA\sl.xlsx')
#         checkSl = sl.isnull().values.any()
#         print(checkSl)

#     while checkEng != 0:
#         eng()
#         raw = int(input("Which raw do you want to edit? "))
#         val = input("What should be the value then? ")
#         editeng()
#         print("your changes have been saved successfully !!")
#         checkEng = england.isnull().sum().sum()

print("Enjoy the match!!!")
# Out:
# ---------------IIT Cricket Premier League 2021---------------
#
# Enjoy the match!!!

# %% [markdown]
# # points table

# %%
# https://www.freecodecamp.org/news/how-to-create-read-update-and-search-through-excel-files-using-python-c70680d811d4/

# %%
# import openpyxl

# myworkbook = load_workbook(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\points_table.xlsx')
# worksheet= myworkbook['Sheet1']

# worksheet['F1']='We are writing to B4'

# %%
# import openpyxl

# theFile = openpyxl.load_workbook(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\team_data\\points_table.xlsx')
# allSheetNames = theFile.sheetnames

# print("All sheet names {} " .format(theFile.sheetnames))


# for sheet in allSheetNames:
#     print("Current sheet name is {}" .format(sheet))
#     currentSheet = theFile[sheet]
#     # print(currentSheet['B4'].value)

#     #print max numbers of rows and columns for each sheet
#     #print(currentSheet.max_row)
#     #print(currentSheet.max_column)

#     for row in range(1, currentSheet.max_row + 1):
#         #print(row)
#         for column in "B":  # Here you can add or reduce the columns
#             cell_name = "{}{}".format(column, row)
#             #print(cell_name)
#             print("cell position {} has value {}".format(cell_name, currentSheet[cell_name].value))
#             # ws[cell_name] = 4
#             currentSheet[cell_name] = 4

# %%
# import pandas as pd
# from openpyxl import load_workbook

# wb = load_workbook(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\team_data\\points_table.xlsx')
# ws = wb.active


# for row in ws.values:
#    for value in row:
#      print(value)

# %% [markdown]
# # Generate random match:

# %%
# import random


#assinging teams to groups
Group_A = [Mumbai_India,Chennai_SouthAfrica,Delhi_NewZealand,RoyalChallengers_Bangladesh ]
Group_B = [Rajastan_Australia,Kolkata_England,Punjab_Pakistan,Sunrisers_SriLanka]



match_count = {} 
all_teams = [Mumbai_India[0],Chennai_SouthAfrica[0],Delhi_NewZealand[0],RoyalChallengers_Bangladesh[0],Rajastan_Australia[0],Kolkata_England[0],Punjab_Pakistan[0],Sunrisers_SriLanka[0]]


while len(all_teams) > 0:
    key = all_teams.pop(0)
    match_count[key] = 0 

print(match_count)
# Out:
# {'Mumbai_India': 0, 'Chennai_SouthAfrica': 0, 'Delhi_NewZealand': 0, 'RoyalChallengers_Bangladesh': 0, 'Rajastan_Australia': 0, 'Kolkata_England': 0, 'Punjab_Pakistan': 0, 'Sunrisers_SriLanka': 0}

# %%
match_between_A = random.sample(Group_A, 2)
match_between_B = random.sample(Group_B, 2)



chosen_match = [match_between_A,match_between_B]
match_between = random.choice(chosen_match)


print(match_between)
# Out:
# [['Sunrisers_SriLanka', 'E:\\\\IIT\\\\1st Year\\\\1st Trimester\\\\CM1601 [PRO]  Programming Fundamentals\\\\Course Work\\\\team_data\\\\Sunrisers_SriLanka\\\\Sunrisers_SriLanka.xlsx'], ['Kolkata_England', 'E:\\\\IIT\\\\1st Year\\\\1st Trimester\\\\CM1601 [PRO]  Programming Fundamentals\\\\Course Work\\\\team_data\\\\Kolkata_England\\\\Kolkata_England.xlsx']]

# %%
points_table = pd.read_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\tournament\\points_table.xlsx')
df_points_table = pd.DataFrame(points_table)
df_points_table
# Out:
#                        Group A  Matches_A  Won  Lost  Points  Unnamed: 5  \
# 0                 Mumbai_India          0    0     0       0         NaN
# 1          Chennai_SouthAfrica          1    0     0       0         NaN
# 2             Delhi_NewZealand          1    0     0       0         NaN
# 3  RoyalChallengers_Bangladesh          2    0     0       0         NaN
#
#               Group B  Matches_B  Won.1  Lost.1  Points.1
# 0  Rajastan_Australia          0      0       0         0
# 1     Kolkata_England          0      0       0         0
# 2     Punjab_Pakistan          0      0       0         0
# 3  Sunrisers_SriLanka          0      0       0         0

# %%
for team in match_between:
    if(team in Group_A):
        group = "Group A"
    else:
        group = "Group B"
    find_team_index = df_points_table.index[df_points_table[group] ==  team[0]].tolist()
    if(group == "Group A"):
        current_match_count = df_points_table.at[find_team_index[0],'Matches_A']
        df_points_table.at[find_team_index,'Matches_A']= current_match_count+1
    else:
        current_match_count = df_points_table.at[find_team_index[0],'Matches_B']
        df_points_table.at[find_team_index,'Matches_B']= current_match_count+1
    print(find_team_index,group,current_match_count)
# Out:
# [3] Group B 0
# [1] Group B 0

# %%
df_points_table
# Out:
#                        Group A  Matches_A  Won  Lost  Points  Unnamed: 5  \
# 0                 Mumbai_India          0    0     0       0         NaN
# 1          Chennai_SouthAfrica          1    0     0       0         NaN
# 2             Delhi_NewZealand          1    0     0       0         NaN
# 3  RoyalChallengers_Bangladesh          2    0     0       0         NaN
#
#               Group B  Matches_B  Won.1  Lost.1  Points.1
# 0  Rajastan_Australia          0      0       0         0
# 1     Kolkata_England          1      0       0         0
# 2     Punjab_Pakistan          0      0       0         0
# 3  Sunrisers_SriLanka          1      0       0         0

# %%
# points_table = pd.read_excel(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\tournament\\points_table.xlsx')
# df_points_table = pd.DataFrame(points_table)
# df_points_table

# %%
# Alternative way to update dataframe
# df_points_table.loc[df_points_table['Group A'] == 'RoyalChallengers_Bangladesh', 'Matches'] = 44
# df_points_table

# %%
# find_team_index = df_points_table.index[df_points_table["Group A"] == "RoyalChallengers_Bangladesh"].tolist()
# current_match_count = df_points_table.at[find_team_index[0],'Matches']

# %%
# x = df_points_table.at[3,'Matches']
# df_points_table.at[3,'Matches']= x+88
# df_points_table

# %% [markdown]
# ## Write data to excel file by creating Excel Writer Object from Pandas

# %%
writer = pd.ExcelWriter(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\tournament\\points_table.xlsx',engine='xlsxwriter')   
workbook=writer.book
worksheet=workbook.add_worksheet('Validation')
writer.sheets['Validation'] = worksheet
df_points_table.to_excel(writer,sheet_name='Validation',startrow=0 , startcol=0 ,index=False)   

writer.save()
writer.close()
# Out:
# C:\Users\nadun\AppData\Local\Programs\Python\Python39\lib\site-packages\xlsxwriter\workbook.py:339: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")

# %% [markdown]
# # The team who won the toss takes the decision (Ball first or bat first)

# %%
# import random

coin = ["heads", "tails"]
options = ['bat','bowl']
team_to_bat = []
team_to_bowl = []

visiting_team = random.choice(match_between)

if visiting_team in match_between:
    match_between.remove(visiting_team)

home_team = match_between[0]


toss = random.choice(coin)            # This simulates the coin being tossed
choose = random.choice(options)       # This simulates the visiting team choose bat or bowl
selection = random.choice(coin)       # This simulates the visiting team choose head or tails

print('Home Team', home_team[0])
print('Visiting Team', visiting_team[0])

if selection == toss:
    print(visiting_team[0], 'won the toss and chose to', choose)
    if choose == options[0]:
        team_to_bat = visiting_team
        team_to_bowl = home_team
    else:
        team_to_bat = home_team
        team_to_bowl = visiting_team
    
else:
    print(home_team[0], 'won the toss and chose to', choose)
    if choose == options[0]:
        team_to_bat = home_team
        team_to_bowl = visiting_team
    else:
        team_to_bat = visiting_team
        team_to_bowl = home_team
# Out:
# Home Team Kolkata_England
# Visiting Team Sunrisers_SriLanka
# Kolkata_England won the toss and chose to bowl

# %%
print('team_to_bat', team_to_bat[0])
print('team_to_bowl', team_to_bowl[0])
# Out:
# team_to_bat Sunrisers_SriLanka
# team_to_bowl Kolkata_England

# %% [markdown]
# # Then program initiates the first innings.
# # Scores of each batsman, balls took for scoring, wickets by bowlers, overs, fall of wickets, the method of the dismissal, final score of the innings

# %%
# import random
# import pandas as pd
# from operator import itemgetter


first_ing_total = 0
first_ing_wickets = 0
balls = 1
TOTAL_WICKETS = 10
TOTAL_BALLS = 120
score_card_first_ing = []


batsman_onstrike = [['name', 0, 0], True]
batsman_offstrike = [['name', 0, 0], False]


bowler_onstrike = []



# batsman_name , runs , balls_faced , method of dismissal , bowler
#importing batting team
batting_url = team_to_bat[1]
batting_team = pd.read_excel(batting_url)
#converting excel to python list
yet_to_bat = batting_team.values.tolist()        

# bowlers_name , balls , runs , wickets
#importing bowling team
bowling_url = team_to_bowl[1]
bowling_team = pd.read_excel(bowling_url)
#converting excel to python list
bowling_team_list = bowling_team.values.tolist()  


yet_to_bowl = []

for i in reversed(range(len(bowling_team_list))):
    if len(yet_to_bowl) < 5 :
        yet_to_bowl.append([bowling_team_list[i][0], 0, 0, 0])



dismissed_batsmen = []
batsman_list = []



# method of dismissal
method_of_dismissal = ['Bowled', 'Caught', 'LBW']


bowler_score = 0  # score counting variable for bowler
batter_score = 0  # score counting variable for batsman


# opening batsmen coming to the field
batsman_onstrike[0] = yet_to_bat.pop(0)
batsman_offstrike[0] = yet_to_bat.pop(0)


# opening bowler
bowler_onstrike = yet_to_bowl.pop(0)


while (balls < (TOTAL_BALLS+1)):
    if first_ing_wickets == TOTAL_WICKETS:
        break
    else:
        if ((balls-1) > 0 and (balls-1) % 6 == 0) and (len(yet_to_bowl)) > 0:
            yet_to_bowl.append(bowler_onstrike)
            # bowler_onstrike[0] = []
            bowler_onstrike = yet_to_bowl.pop(0)

        # get random scores for bowler and batsman
        bowler_score = random.randint(1, 6)
        batter_score = random.randint(0, 6)

        if bowler_score == batter_score:
            # adding wickets to bowler
            current_bowler_onstrike_first_ing_wickets = 0
            current_bowler_onstrike_first_ing_wickets = bowler_onstrike[3]
            bowler_onstrike[3] = current_bowler_onstrike_first_ing_wickets + 1
            # adding balls to batsman
            current_batsman_onstrike_balls = batsman_onstrike[0][2]
            batsman_onstrike[0][2] = current_batsman_onstrike_balls + 1

            # moving the dismissed_batsmen to dismissed_batsmen array
            dismissed_batsmen.append(batsman_onstrike[0])


            # adding method of dismissal to batsman
            current_batsman_method_of_dismissal = random.choices(
                method_of_dismissal)
            batsman_onstrike[0][3] = current_batsman_method_of_dismissal[0]

            # adding dismissed bowler name to batsman
            current_batsman_bowler_dismissed = batsman_onstrike[0][4]
            batsman_onstrike[0][4] = current_batsman_bowler_dismissed + \
                str(bowler_onstrike[0])

            # fall of wickets
            print('FOW', first_ing_total, ' --> ', first_ing_wickets+1, ' on over -', int(balls/6), '.', (balls) % 6 , batsman_onstrike[0][0])

            #bring new batsman to the crease (batsman_onstrike)
            if len(yet_to_bat) > 0:
                batsman_onstrike[0] = []
                batsman_onstrike[0] = yet_to_bat.pop(0)


            # out - add wicket to wickets
            first_ing_wickets += 1

        else:
            # adding batter_score to current_batsman
            current_batsman_onstrike_score = 0
            current_batsman_onstrike_score = batsman_onstrike[0][1]
            batsman_onstrike[0][1] = current_batsman_onstrike_score + batter_score

            # adding balls to current_batsman
            current_batsman_onstrike_balls = batsman_onstrike[0][2]
            batsman_onstrike[0][2] = current_batsman_onstrike_balls + 1

            # adding batter_score to current_bowler
            current_bowler_onstrike_runs = 0
            current_bowler_onstrike_runs = bowler_onstrike[2]
            bowler_onstrike[2] = current_bowler_onstrike_runs + batter_score

            # swapping onstrike batsman when strike rotates
            if batter_score == 1 or batter_score == 3:
                current_batsman = batsman_onstrike[0]
                # swapping onstrike batsman
                batsman_onstrike[0] = batsman_offstrike[0]
                batsman_offstrike[0] = current_batsman
            else:
                pass  # when batter_score is not swapping

            # add batter score to first_ing_total
            first_ing_total += batter_score
            
            #adding extras to the total
            # extras_first_ing = random.randint(1,10)                                                       #check this
            # first_ing_total += extras

    # adding balls to bowler
    current_bowler_onstrike_balls = 0
    current_bowler_onstrike_balls = bowler_onstrike[1]
    bowler_onstrike[1] = current_bowler_onstrike_balls + 1
    balls += 1

# last dismissed batsman
last_dismissal = dismissed_batsmen[-1]


#add dismissed_batsmen to batsman_list
batsman_list = dismissed_batsmen


#add each batsman in yet_to_bat to batsman_list array for displaying purposes
if len(yet_to_bat) > 0 :
    for i in range(len(yet_to_bat)):
        batsman_list.append(yet_to_bat[i])


#add on and off strike batsmen to batsman_list
if first_ing_wickets != TOTAL_WICKETS:
    batsman_onstrike[0][3] = '* NOT OUT'
    batsman_list.append(batsman_onstrike[0])

batsman_offstrike[0][3] = 'NOT OUT'
batsman_list.append(batsman_offstrike[0])


#add batsman_list to score_card_first_ing
score_card_first_ing = batsman_list


#add bowlers to bowler_list_first_ing
bowler_list_first_ing = yet_to_bowl
bowler_list_first_ing.append(bowler_onstrike)


# sort score_card_first_ing to the original batting order
sorted_list = sorted(score_card_first_ing, key=itemgetter(5))



# convert score_card_first_ing to a data frame for displaying
df_score_card_first_ing = pd.DataFrame(sorted_list)


# convert df_bowler_list_first_ing to a data frame for displaying
df_bowler_list_first_ing = pd.DataFrame(bowler_list_first_ing)
# Out:
# FOW 0  -->  1  on over - 0 . 1 Dinesh Chandimal
# FOW 0  -->  2  on over - 0 . 2 Charith Asalanka
# FOW 22  -->  3  on over - 2 . 0 Dhananjaya de Silva
# FOW 30  -->  4  on over - 2 . 4 Pathum Nissanka
# FOW 91  -->  5  on over - 6 . 1 Bhanuka Rajapakse
# FOW 103  -->  6  on over - 7 . 2 Dasun Shanka(C)
# FOW 103  -->  7  on over - 7 . 4 Chamika Karunarathne
# FOW 176  -->  8  on over - 12 . 4 Wanindu Hasaranga
# FOW 185  -->  9  on over - 13 . 2 Dushmantha Chameera
# FOW 194  -->  10  on over - 13 . 5 Lahiru Kumara

# %%
print('\nTotal-', first_ing_total, '\nwickets -', first_ing_wickets, '\novers -', int((balls-1)/6), '.', (balls-1) % 6, '\nballs', (balls-1))
# print('Extras - ',extras_first_ing)
print('\nLast dismissal', last_dismissal)
# Out:
# Total- 194
# wickets - 10
# overs - 13 . 5
# balls 83
#
# Last dismissal ['Lahiru Kumara', 9, 3, 'Caught', ' Chris Woakes', 11]

# %%
new_headers = ['Batting','Runs','Balls Faced','MOD','Bowler','Batting No']
df_score_card_first_ing.columns = new_headers
df_score_card_first_ing_without_index = df_score_card_first_ing.set_index('Batting')
df_score_card_first_ing_without_index
# Out:
#                       Runs  Balls Faced      MOD         Bowler  Batting No
# Batting
# Dinesh Chandimal         0            1   Caught      Mark Wood           1
# Pathum Nissanka         20            8      LBW   Chris Jordan           2
# Charith Asalanka         0            1      LBW      Mark Wood           3
# Dhananjaya de Silva      7            4      LBW    Adil Rashid           4
# Bhanuka Rajapakse       41           13   Caught    Adil Rashid           5
# Dasun Shanka(C)         31           14   Bowled   Chris Jordan           6
# Wanindu Hasaranga       42           19      LBW   Chris Jordan           7
# Chamika Karunarathne     0            2   Bowled   Chris Jordan           8
# Dushmantha Chameera     39           16   Bowled   Chris Woakes           9
# Maheesh Theekshana       5            2  NOT OUT                         10
# Lahiru Kumara            9            3   Caught   Chris Woakes          11

# %%
overs = str(int((balls-1)/6)) + '.'+ str((balls-1) % 6)
first_ing_summary = [[first_ing_total,first_ing_wickets, overs,(balls-1)]]

df_first_ing_summary = pd.DataFrame(first_ing_summary, columns = ['Total' , 'Wickets' , 'Overs' ,'Balls'])
print(df_first_ing_summary.to_string(index = False))
# Out:
#  Total  Wickets Overs  Balls
#    194       10  13.5     83

# %%
new_headers = ['Bowling','Balls','Runs','Wickets']
df_bowler_list_first_ing.columns = new_headers
df_bowler_list_first_ing_without_index = df_bowler_list_first_ing.set_index('Bowling')
df_bowler_list_first_ing_without_index
# Out:
#                   Balls  Runs  Wickets
# Bowling
# Liam Livingstone     12    36        0
# Mark Wood            18    41        2
# Adil Rashid          18    40        2
# Chris Jordan         18    29        4
# Chris Woakes         17    48        2

# %% [markdown]
# ## Write data to excel file by creating Excel Writer Object from Pandas

# %%
def foo(username):
    first = "/'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\tournament\\matches/"
    last = "/test.xlsx"
    result = first + username + last 
    return result  
print(foo)
# Out:
# <function foo at 0x00000213E53705E0>

# %%
filename_match = str(visiting_team[0]) + '_vs_' + str(home_team[0])
match_file_path = r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\tournament\\matches\\'+ filename_match +'.xlsx'

writer = pd.ExcelWriter(match_file_path,engine='xlsxwriter')   
workbook=writer.book
worksheet=workbook.add_worksheet('Validation')
writer.sheets['Validation'] = worksheet


df_score_card_first_ing.to_excel(writer,sheet_name='Validation',startrow=0 , startcol=0, index=False)


df_first_ing_summary.to_excel(writer,sheet_name='Validation',startrow=14 , startcol=0, index=False)
# first_ing_total.to_excel(writer,sheet_name='Validation',startrow=15 , startcol=0, index=False)
# first_ing_wickets.to_excel(writer,sheet_name='Validation',startrow=16 , startcol=0, index=False)

df_bowler_list_first_ing.to_excel(writer,sheet_name='Validation',startrow=19, startcol=0, index=False)  

writer.save()
writer.close()
# Out:
# C:\Users\nadun\AppData\Local\Programs\Python\Python39\lib\site-packages\xlsxwriter\workbook.py:339: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")

# %% [markdown]
# # Next the second innings start and as explained above the algorithm needs to generate random figures.

# %%
# import random
# import pandas as pd
# from operator import itemgetter


second_ing_total = 0
second_ing_wickets = 0
balls = 1
TOTAL_WICKETS = 10
TOTAL_BALLS = 120
score_card_second_ing = []


batsman_onstrike = [['name', 0, 0], True]
batsman_offstrike = [['name', 0, 0], False]


bowler_onstrike = []


# batsman_name , runs , balls_faced , method of dismissal , bowler
#importing batting team
batting_url = team_to_bowl[1]
batting_team = pd.read_excel(batting_url)
#converting excel to python list
yet_to_bat = batting_team.values.tolist()   




# bowlers_name , balls , runs , wickets
#importing bowling team
bowling_url = team_to_bat[1]
bowling_team = pd.read_excel(bowling_url)
#converting excel to python list
bowling_team_list = bowling_team.values.tolist()  


yet_to_bowl = []


for i in reversed(range(len(bowling_team_list))):
    if len(yet_to_bowl) < 5 :
        yet_to_bowl.append([bowling_team_list[i][0], 0, 0, 0])



dismissed_batsmen = []
batsman_list = []



# method of dismissal
method_of_dismissal = ['Bowled', 'Caught', 'LBW']


bowler_score = 0  # score counting variable for bowler
batter_score = 0  # score counting variable for batsman


# opening batsmen coming to the field
batsman_onstrike[0] = yet_to_bat.pop(0)
batsman_offstrike[0] = yet_to_bat.pop(0)


# opening bowler
bowler_onstrike = yet_to_bowl.pop(0)


while (balls < (TOTAL_BALLS+1)):
    if ( (second_ing_wickets == TOTAL_WICKETS) or (second_ing_total > first_ing_total) ) :
        break
    else:
        if ((balls-1) > 0 and (balls-1) % 6 == 0) and (len(yet_to_bowl)) > 0:
            yet_to_bowl.append(bowler_onstrike)
            # bowler_onstrike[0] = []
            bowler_onstrike = yet_to_bowl.pop(0)

        # get random scores for bowler and batsman
        bowler_score = random.randint(1, 6)
        batter_score = random.randint(0, 6)

        if bowler_score == batter_score:
            # adding wickets to bowler
            current_bowler_onstrike_second_ing_wickets = 0
            current_bowler_onstrike_second_ing_wickets = bowler_onstrike[3]
            bowler_onstrike[3] = current_bowler_onstrike_second_ing_wickets + 1
            # adding balls to batsman
            current_batsman_onstrike_balls = batsman_onstrike[0][2]
            batsman_onstrike[0][2] = current_batsman_onstrike_balls + 1

            # moving the dismissed_batsmen to dismissed_batsmen array
            dismissed_batsmen.append(batsman_onstrike[0])


            # adding method of dismissal to batsman
            current_batsman_method_of_dismissal = random.choices(
                method_of_dismissal)
            batsman_onstrike[0][3] = current_batsman_method_of_dismissal[0]

            # adding dismissed bowler name to batsman
            current_batsman_bowler_dismissed = batsman_onstrike[0][4]
            batsman_onstrike[0][4] = current_batsman_bowler_dismissed + \
                str(bowler_onstrike[0])

            # fall of wickets
            print('FOW', second_ing_total, ' --> ', second_ing_wickets+1, ' on over -', int(balls/6), '.', (balls) % 6 , batsman_onstrike[0][0])

            #bring new batsman to the crease (batsman_onstrike)
            if len(yet_to_bat) > 0:
                batsman_onstrike[0] = []
                batsman_onstrike[0] = yet_to_bat.pop(0)


            # out - add wicket to wickets
            second_ing_wickets += 1



        else:
            # adding batter_score to current_batsman
            current_batsman_onstrike_score = 0
            current_batsman_onstrike_score = batsman_onstrike[0][1]
            batsman_onstrike[0][1] = current_batsman_onstrike_score + batter_score

            # adding balls to current_batsman
            current_batsman_onstrike_balls = batsman_onstrike[0][2]
            batsman_onstrike[0][2] = current_batsman_onstrike_balls + 1

            # adding batter_score to current_bowler
            current_bowler_onstrike_runs = 0
            current_bowler_onstrike_runs = bowler_onstrike[2]
            bowler_onstrike[2] = current_bowler_onstrike_runs + batter_score

            # swapping onstrike batsman when strike rotates
            if batter_score == 1 or batter_score == 3:
                current_batsman = batsman_onstrike[0]
                # swapping onstrike batsman
                batsman_onstrike[0] = batsman_offstrike[0]
                batsman_offstrike[0] = current_batsman
            else:
                pass  # when batter_score is not swapping

            # add batter score to second_ing_total
            second_ing_total += batter_score
            
            #adding extras to the total
            # extras_second_ing = random.randint(1,10)                                                       #check this
            # second_ing_total += extras


    # adding balls to bowler
    current_bowler_onstrike_balls = 0
    current_bowler_onstrike_balls = bowler_onstrike[1]
    bowler_onstrike[1] = current_bowler_onstrike_balls + 1
    balls += 1


# last dismissed batsman
last_dismissal = dismissed_batsmen[-1]


#add dismissed_batsmen to batsman_list
batsman_list = dismissed_batsmen


#add each batsman in yet_to_bat to batsman_list array for displaying purposes
if len(yet_to_bat) > 0 :
    for i in range(len(yet_to_bat)):
        batsman_list.append(yet_to_bat[i])


#add on and off strike batsmen to batsman_list
if second_ing_wickets != TOTAL_WICKETS:
    batsman_onstrike[0][3] = '* NOT OUT'
    batsman_list.append(batsman_onstrike[0])

batsman_offstrike[0][3] = 'NOT OUT'
batsman_list.append(batsman_offstrike[0])


#add batsman_list to score_card_second_ing
score_card_second_ing = batsman_list


# sort score_card_second_ing to the original batting order
sorted_list = sorted(score_card_second_ing, key=itemgetter(5))


#add bowlers to bowler_list_second_ing
bowler_list_second_ing = yet_to_bowl
bowler_list_second_ing.append(bowler_onstrike)


# convert df_score_card_second_ing to a data frame for displaying
df_score_card_second_ing = pd.DataFrame(sorted_list)


# convert df_bowler_list_second_ing to a data frame for displaying
df_bowler_list_second_ing = pd.DataFrame(bowler_list_second_ing)
# Out:
# FOW 15  -->  1  on over - 1 . 0 Jason Roy
# FOW 23  -->  2  on over - 1 . 3 Dawid Malan
# FOW 29  -->  3  on over - 1 . 5 Jonny Bairstow
# FOW 37  -->  4  on over - 2 . 3 Eoin Morgan(C)
# FOW 73  -->  5  on over - 4 . 2 Moeen Ali
# FOW 74  -->  6  on over - 4 . 4 Jos Buttler
# FOW 74  -->  7  on over - 4 . 5 Chris Woakes
# FOW 83  -->  8  on over - 5 . 3 Chris Jordan
# FOW 99  -->  9  on over - 7 . 0 Liam Livingstone
# FOW 105  -->  10  on over - 7 . 4 Mark Wood

# %%
print('\nTotal-', second_ing_total, '\nwickets -', second_ing_wickets, '\novers -', int((balls-1)/6), '.', (balls-1) % 6, '\nballs', (balls-1))
# print('Extras',extras_second_ing)
print('\nLast dismissal', last_dismissal)
# Out:
# Total- 105
# wickets - 10
# overs - 7 . 4
# balls 46
#
# Last dismissal ['Mark Wood', 6, 4, 'Caught', ' Dushmantha Chameera', 11]

# %%
new_headers = ['Batting','Runs','Balls Faced','MOD','Bowler','Batting No']
df_score_card_second_ing.columns = new_headers
df_score_card_second_ing_without_index = df_score_card_second_ing.set_index('Batting')
df_score_card_second_ing_without_index
# Out:
#                   Runs  Balls Faced      MOD                Bowler  Batting No
# Batting
# Jason Roy           12            4   Bowled         Lahiru Kumara           1
# Jos Buttler         36           11   Bowled     Wanindu Hasaranga           2
# Dawid Malan          8            3   Bowled    Maheesh Theekshana           3
# Jonny Bairstow       6            2   Bowled    Maheesh Theekshana           4
# Eoin Morgan(C)       8            4   Caught   Dushmantha Chameera           5
# Moeen Ali            3            3   Bowled     Wanindu Hasaranga           6
# Liam Livingstone    15           10   Bowled    Maheesh Theekshana           7
# Chris Woakes         0            1   Caught     Wanindu Hasaranga           8
# Chris Jordan         8            3   Caught         Lahiru Kumara           9
# Adil Rashid          3            1  NOT OUT                                10
# Mark Wood            6            4   Caught   Dushmantha Chameera          11

# %%
overs = str(int((balls-1)/6)) + '.'+ str((balls-1) % 6)
second_ing_summary = [[second_ing_total,second_ing_wickets, overs,(balls-1)]]

df_second_ing_summary = pd.DataFrame(second_ing_summary, columns = ['Total' , 'Wickets' , 'Overs' ,'Balls'])
print(df_second_ing_summary.to_string(index = False))
# Out:
#  Total  Wickets Overs  Balls
#    105       10   7.4     46

# %%
new_headers = ['Bowling','Balls','Runs','Wickets']
df_bowler_list_second_ing.columns = new_headers
df_bowler_list_second_ing_without_index = df_bowler_list_second_ing.set_index('Bowling')
df_bowler_list_second_ing_without_index
# Out:
#                       Balls  Runs  Wickets
# Bowling
# Chamika Karunarathne      6    24        0
# Wanindu Hasaranga         6     7        3
# Lahiru Kumara            12    29        2
# Maheesh Theekshana       12    28        3
# Dushmantha Chameera      10    17        2

# %% [markdown]
# ## Write data to excel file by creating Excel Writer Object from Pandas

# %%
from openpyxl import load_workbook

book = load_workbook(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\tournament\\matches\\'+ filename_match + '.xlsx')
writer = pd.ExcelWriter(r'E:\\IIT\\1st Year\\1st Trimester\\CM1601 [PRO]  Programming Fundamentals\\Course Work\\tournament\\matches\\'+ filename_match + '.xlsx', engine='openpyxl') 
writer.book = book

writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

df_score_card_second_ing.to_excel(writer,sheet_name='Validation',startrow=0 , startcol=9, index=False)  

df_second_ing_summary.to_excel(writer,sheet_name='Validation',startrow=14 , startcol=9, index=False)


# second_ing_total.to_excel(writer,sheet_name='Validation',startrow=15 , startcol=9, index=False)
# second_ing_wickets.to_excel(writer,sheet_name='Validation',startrow=16 , startcol=9, index=False)

df_bowler_list_second_ing.to_excel(writer,sheet_name='Validation',startrow=19, startcol=9, index=False)  

writer.save()
writer.close()

# %% [markdown]
# # Display match summary for a given match

# %% [markdown]
# ## Toss

# %%
if selection == toss:
    print(visiting_team[0].replace('_', ' '), 'won the toss and chose to', choose)
else:
    print(home_team[0].replace('_', ' '), 'won the toss and chose to', choose)
# Out:
# Kolkata England won the toss and chose to bowl

# %% [markdown]
# ## first innings top performers

# %%
print(team_to_bat[0].replace('_', ' '))
print(df_score_card_first_ing_without_index.nlargest(4, 'Runs'))


print('\n',team_to_bowl[0].replace('_', ' '))
print(df_bowler_list_first_ing_without_index.nlargest(3, 'Wickets'))

print('\nTotal',first_ing_total,'/',first_ing_wickets)
# Out:
# Sunrisers SriLanka
#                      Runs  Balls Faced     MOD         Bowler  Batting No
# Batting
# Wanindu Hasaranga      42           19     LBW   Chris Jordan           7
# Bhanuka Rajapakse      41           13  Caught    Adil Rashid           5
# Dushmantha Chameera    39           16  Bowled   Chris Woakes           9
# Dasun Shanka(C)        31           14  Bowled   Chris Jordan           6
#
#  Kolkata England
#               Balls  Runs  Wickets
# Bowling
# Chris Jordan     18    29        4
# Mark Wood        18    41        2
# Adil Rashid      18    40        2
#
# Total 194 / 10

# %% [markdown]
# ## second innings top performers

# %%
print(team_to_bowl[0].replace('_', ' '))
print(df_score_card_second_ing_without_index.nlargest(4, 'Runs'))

print('\n',team_to_bat[0].replace('_', ' '))
print(df_bowler_list_second_ing_without_index.nlargest(3, 'Wickets'))

print('\nTarget',first_ing_total+1)
print('Total',second_ing_total,'/',second_ing_wickets)
# Out:
# Kolkata England
#                   Runs  Balls Faced     MOD               Bowler  Batting No
# Batting
# Jos Buttler         36           11  Bowled    Wanindu Hasaranga           2
# Liam Livingstone    15           10  Bowled   Maheesh Theekshana           7
# Jason Roy           12            4  Bowled        Lahiru Kumara           1
# Dawid Malan          8            3  Bowled   Maheesh Theekshana           3
#
#  Sunrisers SriLanka
#                     Balls  Runs  Wickets
# Bowling
# Wanindu Hasaranga       6     7        3
# Maheesh Theekshana     12    28        3
# Lahiru Kumara          12    29        2
#
# Target 195
# Total 105 / 10

# %% [markdown]
# ## Match result

# %%
if (second_ing_total > first_ing_total) :
    # print('second_ing_total',second_ing_total)
    print(team_to_bowl[0].replace('_', ' ') , 'Won by' ,TOTAL_WICKETS-second_ing_wickets , 'wickets')
elif (second_ing_total < first_ing_total):
    # print('first_ing_total',first_ing_total) 
    print(team_to_bat[0].replace('_', ' ' ), 'Won by' , (first_ing_total-second_ing_total) , 'runs')
else :
    print('Match drawn')
# Out:
# Sunrisers SriLanka Won by 89 runs

# %% [markdown]
# # Store team/player and match information in a text file

# %% [markdown]
# # Load team/player and match data once you restart the application
